# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-3690/ML-WORKSHOP-PROJECTS/blob/main/RNN(word_prediction)(26_nov).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import SimpleRNN, Embedding, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
print(dir(Tokenizer))   #helps to find the hideen layers
#MAke sure you import specific module before run...
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api_export_path', '_api_export_symbol_id', 'fit_on_sequences', 'fit_on_texts', 'get_config', 'sequences_to_matrix', 'sequences_to_texts', 'sequences_to_texts_generator', 'texts_to_matrix', 'texts_to_sequences', 'texts_to_sequences_generator', 'to_json']

# %%
from tensorflow.keras import Sequential
import tensorflow as tf
#Sample text data
data = ["I love programming", "Programming is fun", "Deep learning is powerfull", "I love deep learning"]

#Tokenizer and sequence data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

#Prepare input data output for RNN
vocab_size = len(tokenizer.word_index) + 1
input_sequences = []
for seq in sequences:
  for i in range(1, len(seq)):
    input_sequences.append(seq[:i+1])

#Pad sequences
max_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_length, padding='pre')

#Split input (X) and target (Y)
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

#Build RNN model
model = Sequential([
    Embedding(vocab_size, 10, input_length=X.shape[1]),
    SimpleRNN(50, activation='tanh'),
    Dense(vocab_size, activation='softmax')
])

#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Train the model
model.fit(X, y, epochs=100, verbose=1)

#Test the model
input_text = "I love deep"
tokenized_input = tokenizer.texts_to_sequences([input_text])[0]
tokenized_input = pad_sequences([tokenized_input], maxlen=max_length - 1, padding='pre')

predicted_word = model.predict(tokenized_input)
predicted_word_index = tf.argmax(predicted_word, axis=1).numpy()[0]
print("Predicted Next Word:", tokenizer.index_word[predicted_word_index])
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.1000 - loss: 2.2113
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1000 - loss: 2.2003
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1000 - loss: 2.1895
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2000 - loss: 2.1789
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3000 - loss: 2.1683
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3000 - loss: 2.1578
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 2.1472
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5000 - loss: 2.1364
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4000 - loss: 2.1254
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5000 - loss: 2.1142
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 2.1025
# Epoch 12/100
# ...
