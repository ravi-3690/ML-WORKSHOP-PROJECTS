# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-3690/ML-WORKSHOP-PROJECTS/blob/main/Image__face_detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import google
print(dir(google))
# Out:
# ['__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'cloud', 'colab']

# %%
#Upload an image
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-11d51a2d-c83d-4fa5-b857-5289a6f5e93a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11d51a2d-c83d-4fa5-b857-5289a6f5e93a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Load haar cascade(pre-trained model) for face detection
cascade_file = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(cascade_file)

# %%
#load the uploaded image
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# %%
#Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
#Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# %%
#Draw rectangles around detected faces
for (x, y, w, h) in faces:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
#Display the result
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=532x533>
